# %%
# Check the trend of investments over the years. To check the trend, find -
# Total number of fundings done in each year.
# Plot a line graph between year and number of fundings. Take year on x-axis and number of fundings on y-axis.
# Print year-wise total number of fundings also. Print years in ascending order.
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd

file_path=open("startup_funding.csv")
# data=csv.DictReader(file_path, skipinitialspace=True)
startup=pd.read_csv("startup_funding.csv")
df=startup.copy()

df['year']=(df['Date']).str[-4:]
d={}
year=[]
funding=[]
for key in df.year:
    if key in d:
        d[key]+=1
    else:
        d[key]=1

for i in d:
    year.append(i)
    funding.append(d[i])
    
year=np.array(year)
funding=np.array(funding)

index=year.argsort()
year=year[index[:]]
funding=funding[index[:]]

plt.plot(year,funding)
plt.show()

for i in range(len(year)):
    print(year[i],funding[i])
# print(df['year'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       7 import csv
#       8 import pandas as pd
# ---> 10 file_path=open("startup_funding.csv")
#      11 # data=csv.DictReader(file_path, skipinitialspace=True)
#      12 startup=pd.read_csv("startup_funding.csv")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'startup_funding.csv'

# %%
# Find out which cities are generally chosen for starting a startup.
# Find top 10 Indian cities which have most number of startups ?
# Plot a pie chart and visualise it.
# Print the city name and number of startups in that city also.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_start=pd.read_csv('startup_funding.csv',encoding='utf-8')
df_start['CityLocation'].dropna(inplace=True)

def separateCity(city):
    return city.split('/')[0].strip()
df_start['CityLocation']=df_start['CityLocation'].apply(separateCity)
# print(df_start['CityLocation'])
df_start['CityLocation'].replace("Delhi","New Delhi",inplace=True)
df_start['CityLocation'].replace("bangalore","Bangalore",inplace=True)
df_start['CityLocation'].dropna(inplace=True)
# city_number=df_start['CityLocation'].value_counts()[0:10]
d={}
for i in df_start.CityLocation:
    if i in d:
        d[i]+=1
    else:
        d[i]=1

# print(d)
city=[]
fre=[]
for  i in d:
    city.append(i)
    fre.append(d[i])
city=np.array(city)
fre=np.array(fre)

index=np.argsort(fre)[::-1]

city=city[index][:10]
fre=fre[index][:10]
for  i in range(len(fre)):
    
    print(city[i],fre[i])

plt.pie(fre,labels=city,autopct="%0.2f")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       6 import numpy as np
#       7 import matplotlib.pyplot as plt
# ----> 8 df_start=pd.read_csv('startup_funding.csv',encoding='utf-8')
#       9 df_start['CityLocation'].dropna(inplace=True)
#      11 def separateCity(city):
#
# ...

# %%
# Find out if cities play any role in receiving funding.
# Find top 10 Indian cities with most amount of fundings received. Find out percentage of funding each city has got (among top 10 Indian cities only).
# Print the city and percentage with 2 decimal place after rounding off.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('startup_funding.csv')
df = data.copy()
df.AmountInUSD.dropna(inplace=True)
df.CityLocation.dropna(inplace=True)

def seperateCity(s):
    s = str(s)
    return s.split('/')[0].strip()

df['CityLocation'] = df['CityLocation'].apply(seperateCity)
df['CityLocation'].replace( "Delhi","New Delhi",inplace=True)
df['CityLocation'].replace("bangalore","Bangalore",inplace=True)

df["AmountInUSD"]=df["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))
df["AmountInUSD"]=pd.to_numeric(df["AmountInUSD"])
city_amount=df.groupby('CityLocation')['AmountInUSD'].sum().sort_values(ascending=False)[0:10]
city=city_amount.index
amountCity=city_amount.values
perAmount=np.true_divide(amountCity, amountCity.sum())*100
for i in range(len(city)):
    print(city[i],format(perAmount[i],'.2f'))

# %%
# There are 4 different type of investments. Find out percentage of amount funded for each investment type.
# Plot a pie chart to visualise.
# Print the investment type and percentage of amount funded with 2 decimal places after rounding off.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_start=pd.read_csv('startup_funding.csv',encoding='utf-8')
df_start['InvestmentType'].dropna(inplace=True)#empty value ko drop karne keliye,agar value khali hai toh drop kar ne keliye 
def separateCity(city):
    return city.split('/')[0].strip()
df_start['InvestmentType']=df_start['InvestmentType'].apply(separateCity)
df_start['InvestmentType'].replace("PrivateEquity","Private Equity",inplace=True)
df_start['InvestmentType'].replace("SeedFunding","Seed Funding",inplace=True)
df_start['InvestmentType'].replace("Crowd funding","Crowd Funding",inplace=True)

## Converting "AmountInUSD" into numeric format
df_start["AmountInUSD"] = df_start["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))
df_start["AmountInUSD"] = pd.to_numeric(df_start["AmountInUSD"])
city_amount=df_start.groupby('InvestmentType')['AmountInUSD'].sum().sort_values(ascending=False)[0:10]
city=city_amount.index
amountCity=city_amount.values
perAmount=np.true_divide(amountCity, amountCity.sum())*100
plt.pie(perAmount,labels = city , autopct = "%.2f%%")
plt.axis("equal")
plt.show()
for i in range(len(city)):
    print(city[i],format(perAmount[i],'.2f'))

# %%
# Which type of companies got more easily funding. To answer this question, find -
# Top 5 industries and percentage of the total amount funded to that industry. (among top 5 only)
# Print the industry name and percentage of the amount funded with 2 decimal place after rounding off.
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
file_path=open("startup_funding.csv")
data=csv.DictReader(file_path, skipinitialspace=True)
df=pd.read_csv('startup_funding.csv',encoding='utf-8')
# print(df.columns)
df = df.dropna(subset=['IndustryVertical'])

df['AmountInUSD']=df['AmountInUSD'].str.replace(",","")
df['IndustryVertical'].str.strip()

df['IndustryVertical'].replace(['E-commerce','eCommerce','ECommerce','ecommerce'],'Ecommerce',inplace=True)

df['AmountInUSD'].fillna('0',inplace=True)

np_name=np.array(df['IndustryVertical'])
np_fund=np.array(df['AmountInUSD'],dtype=float)
    
d={}
for i in range(len(np_name)):
    key=np_name[i]
    value=np_fund[i]
    if key in d:
        d[key]=d[key]+value
    else:
        d[key]=value

name=[]
fund=[]
for i in d:
    name.append(i)
    fund.append(d[i])
name=np.array(name)
fund=np.array(fund)
index=np.argsort(fund)[::-1]
name=name[index[:5]]
fund=fund[index[:5]]
for i in range(len(fund)):
    k=(fund[i]/sum(fund))*100
    j=round(k,2)
    print(name[i],j)

# %%
# Find top 5 startups with most amount of total funding.
# Print the startup name in descending order with respect to amount of funding.
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
file_path=open("startup_funding.csv")
data=csv.DictReader(file_path, skipinitialspace=True)
df=pd.read_csv('startup_funding.csv',encoding='utf-8')

df['AmountInUSD']=df['AmountInUSD'].str.replace(",","")
df['StartupName'].replace(["OyoRooms",'OYOfit','OyoRooms','Oyorooms','OYO Rooms'],"Oyo",inplace=True)
df['StartupName'].replace("Paytm Marketplace","Paytm",inplace=True)
df['StartupName'].replace("Ola Cabs","Ola",inplace=True)
df['StartupName'].replace("Flipkart.com","Flipkart",inplace=True)

df['AmountInUSD'].fillna('0',inplace=True)
df['StartupName'].dropna(inplace=True)

names=['Ola','Flipkart','Oyo','Snapdeal','Paytm']
df = df[df['StartupName'].isin(names)]

np_startup=np.array(df['StartupName'])
np_fund=np.array(df['AmountInUSD'],dtype=float)

d={}
for i in range(len(np_startup)):
    key=np_startup[i]
    value=np_fund[i]
    if key in d:
        d[key]=d[key]+value
    else:
        d[key]=value
        
strt=[]
fund=[]
for i in d:
    strt.append(i)
    fund.append(d[i])
np_startup=np.array(strt)
np_fund=np.array(fund)
index=np.argsort(np_fund)[::-1]
np_startup=np_startup[index]
np_fund=np_fund[index]
for i in range(len(np_fund)):
    print(np_startup[i])

# %%
# Find the top 5 startups who received the most number of funding rounds. That means, startups which got fundings maximum number of times.
# Print the startup name in descending order with respect to the number of funding round as integer value.
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
file_path=open("startup_funding.csv")
data=csv.DictReader(file_path, skipinitialspace=True)
df=pd.read_csv('startup_funding.csv',encoding='utf-8')

df['StartupName'].replace(["OyoRooms",'OyoRooms','Oyorooms','OYO Rooms','Oyo Rooms'],"Oyo",inplace=True)
df['StartupName'].replace("Paytm Marketplace","Paytm",inplace=True)
df['StartupName'].replace(["Ola Cabs",'Olacabs','Ola cabs'],"Ola",inplace=True)
df['StartupName'].replace("Flipkart.com","Flipkart",inplace=True)
df['StartupName']=df['StartupName'].str.strip()

# df.dropna(inplace=True)

np_startup=np.array(df['StartupName'])
d={}
for i in np_startup:
    if i in d:
        d[i]+=1
    else:
        d[i]=1
startup=[]
fre=[]
for i in d:
    startup.append(i)
    fre.append(d[i])
np_startup=np.array(startup)
np_fre=np.array(fre)
index=np.argsort(fre)[::-1]
np_startup=np_startup[index[:5]]
np_fre=np_fre[index[:5]]
for i in range(len(np_fre)):
    print(np_startup[i],np_fre[i])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       5 import csv
#       6 import matplotlib.pyplot as plt
# ----> 7 file_path=open("startup_funding.csv")
#       8 data=csv.DictReader(file_path, skipinitialspace=True)
#       9 df=pd.read_csv('startup_funding.csv',encoding='utf-8')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'startup_funding.csv'

# %%
# Find the Investors who have invested maximum number of times.
# Print the investor name and number of times invested as integer value.
